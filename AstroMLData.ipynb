# %% [markdown]
# Notebook computes the original analysis and saves the error free data. Then, the data is run through the network simulator to generate undetected errors and it read again to compute the analysis to test our hypothesis if this impacts scientific conclusions.

# %%
# Necessary installs
# !pip install astroML
# Out:
# Requirement already satisfied: astroML in /Users/prateek/opt/anaconda3/lib/python3.9/site-packages (1.0.2.post1)
# Requirement already satisfied: matplotlib>=3.0 in /Users/prateek/opt/anaconda3/lib/python3.9/site-packages (from astroML) (3.5.1)
# Requirement already satisfied: astropy>=3.0 in /Users/prateek/opt/anaconda3/lib/python3.9/site-packages (from astroML) (5.0.4)
# Requirement already satisfied: scipy>=0.18 in /Users/prateek/opt/anaconda3/lib/python3.9/site-packages (from astroML) (1.7.3)
# Requirement already satisfied: numpy>=1.13 in /Users/prateek/opt/anaconda3/lib/python3.9/site-packages (from astroML) (1.21.5)
# Requirement already satisfied: scikit-learn>=0.18 in /Users/prateek/opt/anaconda3/lib/python3.9/site-packages (from astroML) (1.0.2)
# Requirement already satisfied: PyYAML>=3.13 in /Users/prateek/opt/anaconda3/lib/python3.9/site-packages (from astropy>=3.0->astroML) (6.0)
# Requirement already satisfied: pyerfa>=2.0 in /Users/prateek/opt/anaconda3/lib/python3.9/site-packages (from astropy>=3.0->astroML) (2.0.0)
# Requirement already satisfied: packaging>=19.0 in /Users/prateek/opt/anaconda3/lib/python3.9/site-packages (from astropy>=3.0->astroML) (21.3)
# Requirement already satisfied: cycler>=0.10 in /Users/prateek/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0->astroML) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/prateek/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0->astroML) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/prateek/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0->astroML) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/prateek/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0->astroML) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/prateek/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0->astroML) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/prateek/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0->astroML) (3.0.4)
# Requirement already satisfied: six>=1.5 in /Users/prateek/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.0->astroML) (1.16.0)
# Requirement already satisfied: joblib>=0.11 in /Users/prateek/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.18->astroML) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/prateek/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.18->astroML) (2.2.0)

# %%
# Necessary imports
import numpy as np
from matplotlib import pyplot as plt
from astroML.datasets import fetch_moving_objects
from astroML.plotting.tools import devectorize_axes

# %%
# Helper functions
def black_bg_subplot(*args, **kwargs):
    """Create a subplot with black background"""
    kwargs['facecolor'] = 'k'
    ax = plt.subplot(*args, **kwargs)

    # set ticks and labels to white
    for spine in ax.spines.values():
        spine.set_color('w')

    for tick in ax.xaxis.get_major_ticks() + ax.yaxis.get_major_ticks():
        for child in tick.get_children():
            child.set_color('w')

    return ax

def compute_color(mag_a, mag_i, mag_z, a_crit=-0.1):
    """
    Compute the scatter-plot color using code adapted from
    TCL source used in Parker 2008.
    """
    # define the base color scalings
    R = np.ones_like(mag_i)
    G = 0.5 * 10 ** (-2 * (mag_i - mag_z - 0.01))
    B = 1.5 * 10 ** (-8 * (mag_a + 0.0))

    # enhance green beyond the a_crit cutoff
    G += 10. / (1 + np.exp((mag_a - a_crit) / 0.02))

    # normalize color of each point to its maximum component
    RGB = np.vstack([R, G, B])
    RGB /= RGB.max(0)

    # return an array of RGB colors, which is shape (n_points, 3)
    return RGB.T

# %%
# Original data analysis
# Taken from https://jhepc.github.io/2013/entry3/index.html
# Fetch data and extract the desired quantities
data = fetch_moving_objects(Parker2008_cuts=True)
mag_a = data['mag_a']
mag_i = data['mag_i']
mag_z = data['mag_z']
a = data['aprime']
sini = data['sin_iprime']

# dither: magnitudes are recorded only to ± 0.01
mag_a += -0.005 + 0.01 * np.random.random(size=mag_a.shape)
mag_i += -0.005 + 0.01 * np.random.random(size=mag_i.shape)
mag_z += -0.005 + 0.01 * np.random.random(size=mag_z.shape)

# compute RGB color based on magnitudes
color = compute_color(mag_a, mag_i, mag_z)

#------------------------------------------------------------
# set up the plot
fig = plt.figure(figsize=(10.5, 5), facecolor='k')
fig.subplots_adjust(left=0.08, right=0.95, wspace=0.2,
                    bottom=0.1, top=0.9)

# plot the color-magnitude plot
ax = black_bg_subplot(121)
ax.scatter(mag_a, mag_i - mag_z,
           c=color, s=1, lw=0, edgecolors=color)

# uncomment to convert SVG points to pixels
#devectorize_axes(ax, dpi=400)

ax.plot([0, 0], [-0.8, 0.6], '--w', lw=2)
ax.plot([0, 0.4], [-0.15, -0.15], '--w', lw=2)

ax.set_xlim(-0.3, 0.4)
ax.set_ylim(-0.8, 0.6)

ax.set_xlabel('Optical Color (a*)', color='w')
ax.set_ylabel('Near-IR Color (i - z)', color='w')

# plot the orbital parameters plot
ax = black_bg_subplot(122)
ax.scatter(a, sini,
           c=color, s=1, lw=0, edgecolors=color)

# uncomment to convert SVG points to pixels
#devectorize_axes(ax, dpi=400)

ax.plot([2.5, 2.5], [-0.02, 0.3], '--w')
ax.plot([2.82, 2.82], [-0.02, 0.3], '--w')

ax.set_xlim(2.0, 3.3)
ax.set_ylim(-0.02, 0.3)

ax.set_xlabel('Semi-major Axis (AU)', color='w')
ax.set_ylabel('Sine of Orbital Inclination', color='w')

# label the plot
text_kwargs = dict(color='w', fontsize=14,
                   transform=plt.gca().transAxes,
                   ha='center', va='bottom')

ax.text(0.25, 1.01, 'Inner', **text_kwargs)
ax.text(0.53, 1.01, 'Mid', **text_kwargs)
ax.text(0.83, 1.01, 'Outer', **text_kwargs)

# # Saving the black-background figure requires some extra arguments:
# fig.savefig('asteroids.pdf',
#             facecolor='black',
#             edgecolor='none')

plt.show()
print(len(data))
# Out:
# 33160

# %%
# Save data with no errors
np.savetxt('astroMLData.txt', data, delimiter=',', fmt='%s', header=','.join(data.dtype.names))

# %%
# Take this data and run it through the simulator

# Then, rename OutputFile to astroMLDataWithErrors.txt

# %%
# Load data with undetected errors
data = np.genfromtxt("receivedData.txt", delimiter=',', dtype=None, invalid_raise=False, names = True)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /Users/prateek/Documents/MLED_Project/MLED_Simulator/AstroMLData.ipynb Cell 8 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/prateek/Documents/MLED_Project/MLED_Simulator/AstroMLData.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> # Load data with undetected errors
# ----> <a href='vscode-notebook-cell:/Users/prateek/Documents/MLED_Project/MLED_Simulator/AstroMLData.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> data = np.genfromtxt("receivedData.txt", delimiter=',', dtype=None, invalid_raise=False, names = True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/npyio.py:1793, in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, like)
#    1791     fname = os_fspath(fname)
#    1792 if isinstance(fname, str):
# -> 1793     fid = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1794     fid_ctx = contextlib.closing(fid)
#    1795 else:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/_datasource.py:533, in DataSource.open(self, path, mode, encoding, newline)
#     530     return _file_openers[ext](found, mode=mode,
#     531                               encoding=encoding, newline=newline)
#     532 else:
# --> 533     raise IOError("%s not found." % path)
#
# OSError: receivedData.txt not found.

# %%
# Rerun results with data with undetected errors
# Fetch data and extract the desired quantities
mag_a = data['mag_a']
mag_i = data['mag_i']
mag_z = data['mag_z']
a = data['aprime']
sini = data['sin_iprime']

# dither: magnitudes are recorded only to ± 0.01
mag_a += -0.005 + 0.01 * np.random.random(size=mag_a.shape)
mag_i += -0.005 + 0.01 * np.random.random(size=mag_i.shape)
mag_z += -0.005 + 0.01 * np.random.random(size=mag_z.shape)

# compute RGB color based on magnitudes
color = compute_color(mag_a, mag_i, mag_z)

#------------------------------------------------------------
# set up the plot
fig = plt.figure(figsize=(10.5, 5), facecolor='k')
fig.subplots_adjust(left=0.08, right=0.95, wspace=0.2,
                    bottom=0.1, top=0.9)

# plot the color-magnitude plot
ax = black_bg_subplot(121)
ax.scatter(mag_a, mag_i - mag_z,
           c=color, s=1, lw=0, edgecolors=color)

# uncomment to convert SVG points to pixels
#devectorize_axes(ax, dpi=400)

ax.plot([0, 0], [-0.8, 0.6], '--w', lw=2)
ax.plot([0, 0.4], [-0.15, -0.15], '--w', lw=2)

ax.set_xlim(-0.3, 0.4)
ax.set_ylim(-0.8, 0.6)

ax.set_xlabel('Optical Color (a*)', color='w')
ax.set_ylabel('Near-IR Color (i - z)', color='w')

# plot the orbital parameters plot
ax = black_bg_subplot(122)
ax.scatter(a, sini,
           c=color, s=1, lw=0, edgecolors=color)

# uncomment to convert SVG points to pixels
#devectorize_axes(ax, dpi=400)

ax.plot([2.5, 2.5], [-0.02, 0.3], '--w')
ax.plot([2.82, 2.82], [-0.02, 0.3], '--w')

ax.set_xlim(2.0, 3.3)
ax.set_ylim(-0.02, 0.3)

ax.set_xlabel('Semi-major Axis (AU)', color='w')
ax.set_ylabel('Sine of Orbital Inclination', color='w')

# label the plot
text_kwargs = dict(color='w', fontsize=14,
                   transform=plt.gca().transAxes,
                   ha='center', va='bottom')

ax.text(0.25, 1.01, 'Inner', **text_kwargs)
ax.text(0.53, 1.01, 'Mid', **text_kwargs)
ax.text(0.83, 1.01, 'Outer', **text_kwargs)

# # Saving the black-background figure requires some extra arguments:
# fig.savefig('asteroidsWithErrors.pdf',
#             facecolor='black',
#             edgecolor='none')

plt.show()
print(len(data))
# Out:
# 33160

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

file1 = "astroMLDataLarge.csv"
file2 = "astroMLDataLargeWithErrors.csv"
df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)

# %%
# For simplicity, let's say we're comparing the 'ra' and 'dec' columns
ra1, dec1 = df1['ra'], df1['dec']
ra2, dec2 = df2['ra'], df2['dec']

# Compute the differences
delta_ra = ra2 - ra1
delta_dec = dec2 - dec1

# Now we create the scatter plot
plt.figure(figsize=(10, 8))
plt.scatter(ra1, dec1, color='blue', label='Dataset 1')
plt.scatter(ra2, dec2, color='red', label='Dataset 2')

# Draw lines or arrows connecting the points from dataset 1 to dataset 2
for r1, d1, dr, dd in zip(ra1, dec1, delta_ra, delta_dec):
    plt.arrow(r1, d1, dr, dd, color='green')

plt.xlabel('RA')
plt.ylabel('Dec')
plt.title('Comparison of object positions')
plt.legend()
plt.show()

# %%
magnitudes = ['mag_u', 'mag_g', 'mag_r', 'mag_i', 'mag_z', 'mag_a', 'mag_V', 'mag_B']
for mag in magnitudes:
    plt.figure(figsize=(10, 6))
    plt.hist(df1[mag], bins=30, alpha=0.5, label='File 1', color='blue')
    plt.hist(df2[mag], bins=30, alpha=0.5, label='File 2', color='red')
    plt.xlabel(mag)
    plt.ylabel('Count')
    plt.title('Histogram of {}'.format(mag))
    plt.legend()
    plt.show()

# %%
df1_vlambda_median = np.median(df1['vlambda'])
df1_r_helio_median = np.median(df1['r_helio'])
df2_vlambda_median = np.median(df2['vlambda'])
df2_r_helio_median = np.median(df2['r_helio'])

plt.figure(figsize=(10, 10))
plt.scatter(df1['vlambda'], df1['r_helio'], color='blue', label='File 1', alpha=0.5)
plt.scatter(df2['vlambda'], df2['r_helio'], color='red', label='File 2', alpha=0.5)
for vlambda1, r_helio1, vlambda2, r_helio2 in zip(df1['vlambda'], df1['r_helio'], df2['vlambda'], df2['r_helio']):
    plt.arrow(vlambda1, r_helio1, vlambda2 - vlambda1, r_helio2 - r_helio1, color='green')
plt.xlabel('Radial Velocity')
plt.ylabel('Heliocentric Distance')
plt.title('Radial Velocity vs Heliocentric Distance')
plt.legend()
plt.show()
